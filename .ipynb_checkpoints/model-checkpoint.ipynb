# %% [markdown]
# 1.IMPORT LIBRARIES

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch>=2.0.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from -r requirements.txt (line 2)) (2.8.0)
# Requirement already satisfied: torchvision>=0.15.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from -r requirements.txt (line 3)) (0.23.0)
# Requirement already satisfied: torchaudio>=2.0.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from -r requirements.txt (line 4)) (2.8.0)
# Collecting pytorch-lightning>=2.0.0 (from -r requirements.txt (line 7))
#   Downloading pytorch_lightning-2.5.5-py3-none-any.whl.metadata (20 kB)
# Collecting pytorch-forecasting>=1.0.0 (from -r requirements.txt (line 10))
#   Downloading pytorch_forecasting-1.4.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pandas>=1.5.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from -r requirements.txt (line 13)) (2.3.2)
# Requirement already satisfied: numpy>=1.24.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from -r requirements.txt (line 14)) (2.3.3)
# Requirement already satisfied: matplotlib>=3.7.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from -r requirements.txt (line 17)) (3.10.6)
# Requirement already satisfied: seaborn>=0.12.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from -r requirements.txt (line 18)) (0.13.2)
# Requirement already satisfied: scikit-learn>=1.3.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from -r requirements.txt (line 21)) (1.7.2)
# Collecting pyarrow>=12.0.0 (from -r requirements.txt (line 24))
#   Using cached pyarrow-21.0.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from -r requirements.txt (line 25)) (4.67.1)
# Requirement already satisfied: ipykernel in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from -r requirements.txt (line 28)) (6.30.1)
# Requirement already satisfied: jupyterlab in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from -r requirements.txt (line 29)) (4.4.7)
# Requirement already satisfied: filelock in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: setuptools in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: networkx in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (3.5)
# Requirement already satisfied: jinja2 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (2025.9.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from torchvision>=0.15.0->-r requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: PyYAML>5.4 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from pytorch-lightning>=2.0.0->-r requirements.txt (line 7)) (6.0.2)
# Requirement already satisfied: torchmetrics>0.7.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from pytorch-lightning>=2.0.0->-r requirements.txt (line 7)) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from pytorch-lightning>=2.0.0->-r requirements.txt (line 7)) (25.0)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from pytorch-lightning>=2.0.0->-r requirements.txt (line 7)) (0.15.2)
# Collecting lightning<3.0.0,>=2.0.0 (from pytorch-forecasting>=1.0.0->-r requirements.txt (line 10))
#   Downloading lightning-2.5.5-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: scipy<2.0,>=1.8 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from pytorch-forecasting>=1.0.0->-r requirements.txt (line 10)) (1.16.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from pandas>=1.5.0->-r requirements.txt (line 13)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from pandas>=1.5.0->-r requirements.txt (line 13)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from pandas>=1.5.0->-r requirements.txt (line 13)) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from scikit-learn>=1.3.0->-r requirements.txt (line 21)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from scikit-learn>=1.3.0->-r requirements.txt (line 21)) (3.6.0)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->-r requirements.txt (line 7))
#   Using cached aiohttp-3.12.15-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 17)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 17)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 17)) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 17)) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 17)) (3.2.3)
# Requirement already satisfied: appnope>=0.1.2 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 28)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 28)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 28)) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 28)) (9.5.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 28)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 28)) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 28)) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 28)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 28)) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 28)) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 28)) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 28)) (5.14.3)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyterlab->-r requirements.txt (line 29)) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyterlab->-r requirements.txt (line 29)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyterlab->-r requirements.txt (line 29)) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyterlab->-r requirements.txt (line 29)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyterlab->-r requirements.txt (line 29)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyterlab->-r requirements.txt (line 29)) (0.2.4)
# Requirement already satisfied: anyio in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 29)) (4.10.0)
# Requirement already satisfied: certifi in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 29)) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 29)) (1.0.9)
# Requirement already satisfied: idna in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 29)) (3.10)
# Requirement already satisfied: h11>=0.16 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 29)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (0.22.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 29)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 29)) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 29)) (4.25.1)
# Requirement already satisfied: requests>=2.31 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 29)) (2.32.5)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->-r requirements.txt (line 7))
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->-r requirements.txt (line 7))
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->-r requirements.txt (line 7)) (25.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->-r requirements.txt (line 7))
#   Using cached frozenlist-1.7.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->-r requirements.txt (line 7))
#   Using cached multidict-6.6.4-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->-r requirements.txt (line 7))
#   Using cached propcache-0.3.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->-r requirements.txt (line 7))
#   Using cached yarl-1.20.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (73 kB)
# Requirement already satisfied: sniffio>=1.1 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 29)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (25.1.0)
# Requirement already satisfied: decorator in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 28)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 28)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 28)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 28)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 28)) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 28)) (2.19.2)
# Requirement already satisfied: stack_data in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 28)) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r requirements.txt (line 28)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r requirements.txt (line 28)) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jinja2->torch>=2.0.0->-r requirements.txt (line 2)) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 29)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 29)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 29)) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r requirements.txt (line 28)) (4.4.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (3.3.0)
# Requirement already satisfied: rfc3339-validator in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (0.1.1)
# Requirement already satisfied: fqdn in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (1.5.1)
# Requirement already satisfied: isoduration in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (1.1.0)
# Requirement already satisfied: uri-template in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (6.2.0)
# Requirement already satisfied: defusedxml in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (1.5.1)
# Requirement already satisfied: webencodings in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r requirements.txt (line 28)) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->-r requirements.txt (line 13)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 29)) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 29)) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (1.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=2.0.0->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (2.0.0)
# Requirement already satisfied: pycparser in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (2.23)
# Requirement already satisfied: soupsieve>1.2 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 29)) (2.9.0.20250822)
# Requirement already satisfied: executing>=1.2.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 28)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 28)) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/phanhieu/python-envs/shared-env/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 28)) (0.2.3)
# Downloading pytorch_lightning-2.5.5-py3-none-any.whl (832 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.4/832.4 kB 6.9 MB/s eta 0:00:00
# Downloading pytorch_forecasting-1.4.0-py3-none-any.whl (260 kB)
# Downloading lightning-2.5.5-py3-none-any.whl (828 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 828.5/828.5 kB 9.6 MB/s eta 0:00:00
# Using cached pyarrow-21.0.0-cp313-cp313-macosx_12_0_arm64.whl (31.2 MB)
# Using cached aiohttp-3.12.15-cp313-cp313-macosx_11_0_arm64.whl (466 kB)
# Using cached multidict-6.6.4-cp313-cp313-macosx_11_0_arm64.whl (43 kB)
# Using cached yarl-1.20.1-cp313-cp313-macosx_11_0_arm64.whl (88 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached frozenlist-1.7.0-cp313-cp313-macosx_11_0_arm64.whl (45 kB)
# Using cached propcache-0.3.2-cp313-cp313-macosx_11_0_arm64.whl (41 kB)
# Installing collected packages: pyarrow, propcache, multidict, frozenlist, aiohappyeyeballs, yarl, aiosignal, aiohttp, pytorch-lightning, lightning, pytorch-forecasting
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [pytorch-forecasting]torch-forecasting]
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 frozenlist-1.7.0 lightning-2.5.5 multidict-6.6.4 propcache-0.3.2 pyarrow-21.0.0 pytorch-forecasting-1.4.0 pytorch-lightning-2.5.5 yarl-1.20.1
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
# Core
import torch
import torch.nn as nn

# PyTorch Lightning for training
import pytorch_lightning as pl

# PyTorch Forecasting (TFT and dataset tools)
from pytorch_forecasting import TimeSeriesDataSet, TemporalFusionTransformer
from pytorch_forecasting.metrics import QuantileLoss

# Data handling
import pandas as pd
import numpy as np
from torch.utils.data import DataLoader

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Metrics & utilities
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Progress & debugging
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

device = "mps" if torch.backends.mps.is_available() else "cpu"

# %% [markdown]
# 2.DATA LOADER AND CREATE SEQUENCES

# %%
df = pd.read_csv("data/preprocessed_energy_data_AT_2019_2025.csv")
df = df[['DateUTC','Value']]
# Convert to datetime
df['DateUTC'] = pd.to_datetime(df['DateUTC'])

# Add time index (required by PyTorch Forecasting)
df = df.sort_values("DateUTC").reset_index(drop=True)
df['time_idx'] = np.arange(len(df))

# Add group id (needed even for single time series)
df['series_id'] = "AT"

# Add year/month for possible covariates
df['year'] = df['DateUTC'].dt.year
df['month'] = df['DateUTC'].dt.month

train_cutoff = df[df['year'] < 2025]['time_idx'].max()
max_encoder_length = 60   # how many past days to use
max_prediction_length = 31 # forecast horizon = 31 days (Jan 2025)

print(f"Dataset length: {len(df)}")
print(f"Train cutoff time_idx: {train_cutoff}")
print(f"Max encoder length: {max_encoder_length}")

# Training dataset
training = TimeSeriesDataSet(
    df[lambda x: x.time_idx <= train_cutoff],
    time_idx="time_idx",
    target="Value",
    group_ids=["series_id"],
    min_encoder_length=max_encoder_length//2,
    max_encoder_length=max_encoder_length,
    min_prediction_length=1,
    max_prediction_length=max_prediction_length,
    time_varying_known_reals=["time_idx", "month", "year"],
    time_varying_unknown_reals=["Value"],
    target_normalizer=None,
    add_relative_time_idx=True,
    add_target_scales=True,
    add_encoder_length=True,
)

# Create validation dataset using the CORRECT method
validation = TimeSeriesDataSet.from_dataset(
    training, 
    df, 
    min_prediction_idx=train_cutoff + 1
)

batch_size = 64

# Use PyTorch Forecasting's to_dataloader() method - THIS IS CRITICAL
train_loader = training.to_dataloader(
    batch_size=batch_size, 
    shuffle=True, 
    num_workers=0  # Set to 0 for debugging, then increase later
)

val_loader = validation.to_dataloader(
    batch_size=batch_size, 
    shuffle=False, 
    num_workers=0
)
# Out:
# Dataset length: 54768
# Train cutoff time_idx: 52607
# Max encoder length: 60

# %% [markdown]
# 3.MODEL

# %%
class TemporalFusionTransformer(pl.LightningModule):
    def __init__(self, input_size, hidden_size, output_size, num_layers=2):
        super().__init__()
        self.save_hyperparameters()
        
        # Example architecture - replace with your actual TFT architecture
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, output_size)
        self.criterion = nn.MSELoss()
    
    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        output = self.linear(lstm_out[:, -1, :])  # Take last timestep
        return output
    
    def training_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = self.criterion(y_hat, y)
        self.log('train_loss', loss, prog_bar=True)
        return loss
    
    def validation_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = self.criterion(y_hat, y)
        self.log('val_loss', loss, prog_bar=True)
        return loss
    
    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=0.001)

# Create model instance
tft = TemporalFusionTransformer(
    input_size=10,   # Adjust based on your data
    hidden_size=64,  # Adjust based on your needs
    output_size=1    # Adjust based on your task
)

# Verify the model type
print(f"Model type: {type(tft)}")
print(f"Is LightningModule: {isinstance(tft, pl.LightningModule)}")
# Out:
# Model type: <class '__main__.TemporalFusionTransformer'>
# Is LightningModule: True

# %% [markdown]
# 4.TRAINING PIPELINE

# %%
trainer = pl.Trainer(
    max_epochs=20,
    accelerator="mps",
    gradient_clip_val=0.1,
    enable_checkpointing=True,
    enable_progress_bar=True,
    logger=False,
    enable_model_summary=True,
)

# Now this should work
trainer.fit(tft, train_loader, val_loader)
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type    | Params | Mode
# ----------------------------------------------
# 0 | lstm      | LSTM    | 52.7 K | train
# 1 | linear    | Linear  | 65     | train
# 2 | criterion | MSELoss | 0      | train
# ----------------------------------------------
# 52.8 K    Trainable params
# 0         Non-trainable params
# 52.8 K    Total params
# 0.211     Total estimated model params size (MB)
# 3         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 12
#       1 trainer = pl.Trainer(
#       2     max_epochs=20,
#       3     accelerator="mps",
#    (...)      8     enable_model_summary=True,
#       9 )
#      11 # Now this should work
# ---> 12 trainer.fit(tft, train_loader, val_loader)
#
# File ~/python-envs/shared-env/lib/python3.13/site-packages/pytorch_lightning/trainer/trainer.py:560, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     558 self.training = True
#     559 self.should_stop = False
# --> 560 call._call_and_handle_interrupt(
#     561     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     562 )
#
# File ~/python-envs/shared-env/lib/python3.13/site-packages/pytorch_lightning/trainer/call.py:49, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      47     if trainer.strategy.launcher is not None:
#      48         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 49     return trainer_fn(*args, **kwargs)
#      51 except _TunerExitException:
#      52     _call_teardown_hook(trainer)
#
# File ~/python-envs/shared-env/lib/python3.13/site-packages/pytorch_lightning/trainer/trainer.py:598, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     591     download_model_from_registry(ckpt_path, self)
#     592 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     593     self.state.fn,
#     594     ckpt_path,
#     595     model_provided=True,
#     596     model_connected=self.lightning_module is not None,
#     597 )
# --> 598 self._run(model, ckpt_path=ckpt_path)
#     600 assert self.state.stopped
#     601 self.training = False
#
# File ~/python-envs/shared-env/lib/python3.13/site-packages/pytorch_lightning/trainer/trainer.py:1011, in Trainer._run(self, model, ckpt_path)
#    1006 self._signal_connector.register_signal_handlers()
#    1008 # ----------------------------
#    1009 # RUN THE TRAINER
#    1010 # ----------------------------
# -> 1011 results = self._run_stage()
#    1013 # ----------------------------
#    1014 # POST-Training CLEAN UP
#    1015 # ----------------------------
#    1016 log.debug(f"{self.__class__.__name__}: trainer tearing down")
#
# File ~/python-envs/shared-env/lib/python3.13/site-packages/pytorch_lightning/trainer/trainer.py:1053, in Trainer._run_stage(self)
#    1051 if self.training:
#    1052     with isolate_rng():
# -> 1053         self._run_sanity_check()
#    1054     with torch.autograd.set_detect_anomaly(self._detect_anomaly):
#    1055         self.fit_loop.run()
#
# File ~/python-envs/shared-env/lib/python3.13/site-packages/pytorch_lightning/trainer/trainer.py:1082, in Trainer._run_sanity_check(self)
#    1079 call._call_callback_hooks(self, "on_sanity_check_start")
#    1081 # run eval step
# -> 1082 val_loop.run()
#    1084 call._call_callback_hooks(self, "on_sanity_check_end")
#    1086 # reset logger connector
#
# File ~/python-envs/shared-env/lib/python3.13/site-packages/pytorch_lightning/loops/utilities.py:179, in _no_grad_context.<locals>._decorator(self, *args, **kwargs)
#     177     context_manager = torch.no_grad
#     178 with context_manager():
# --> 179     return loop_run(self, *args, **kwargs)
#
# File ~/python-envs/shared-env/lib/python3.13/site-packages/pytorch_lightning/loops/evaluation_loop.py:145, in _EvaluationLoop.run(self)
#     143     self.batch_progress.is_last_batch = data_fetcher.done
#     144     # run step hooks
# --> 145     self._evaluation_step(batch, batch_idx, dataloader_idx, dataloader_iter)
#     146 except StopIteration:
#     147     # this needs to wrap the `*_step` call too (not just `next`) for `dataloader_iter` support
#     148     break
#
# File ~/python-envs/shared-env/lib/python3.13/site-packages/pytorch_lightning/loops/evaluation_loop.py:437, in _EvaluationLoop._evaluation_step(self, batch, batch_idx, dataloader_idx, dataloader_iter)
#     431 hook_name = "test_step" if trainer.testing else "validation_step"
#     432 step_args = (
#     433     self._build_step_args_from_hook_kwargs(hook_kwargs, hook_name)
#     434     if not using_dataloader_iter
#     435     else (dataloader_iter,)
#     436 )
# --> 437 output = call._call_strategy_hook(trainer, hook_name, *step_args)
#     439 self.batch_progress.increment_processed()
#     441 if using_dataloader_iter:
#     442     # update the hook kwargs now that the step method might have consumed the iterator
#
# File ~/python-envs/shared-env/lib/python3.13/site-packages/pytorch_lightning/trainer/call.py:329, in _call_strategy_hook(trainer, hook_name, *args, **kwargs)
#     326     return None
#     328 with trainer.profiler.profile(f"[Strategy]{trainer.strategy.__class__.__name__}.{hook_name}"):
# --> 329     output = fn(*args, **kwargs)
#     331 # restore current_fx when nested context
#     332 pl_module._current_fx_name = prev_fx_name
#
# File ~/python-envs/shared-env/lib/python3.13/site-packages/pytorch_lightning/strategies/strategy.py:412, in Strategy.validation_step(self, *args, **kwargs)
#     410 if self.model != self.lightning_module:
#     411     return self._forward_redirection(self.model, self.lightning_module, "validation_step", *args, **kwargs)
# --> 412 return self.lightning_module.validation_step(*args, **kwargs)
#
# Cell In[29], line 25, in TemporalFusionTransformer.validation_step(self, batch, batch_idx)
#      23 def validation_step(self, batch, batch_idx):
#      24     x, y = batch
# ---> 25     y_hat = self(x)
#      26     loss = self.criterion(y_hat, y)
#      27     self.log('val_loss', loss, prog_bar=True)
#
# File ~/python-envs/shared-env/lib/python3.13/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/python-envs/shared-env/lib/python3.13/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# Cell In[29], line 12, in TemporalFusionTransformer.forward(self, x)
#      11 def forward(self, x):
# ---> 12     lstm_out, _ = self.lstm(x)
#      13     output = self.linear(lstm_out[:, -1, :])  # Take last timestep
#      14     return output
#
# File ~/python-envs/shared-env/lib/python3.13/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/python-envs/shared-env/lib/python3.13/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/python-envs/shared-env/lib/python3.13/site-packages/torch/nn/modules/rnn.py:1074, in LSTM.forward(self, input, hx)
#    1072         hx = self.permute_hidden(hx, sorted_indices)
#    1073 else:
# -> 1074     if input.dim() not in (2, 3):
#    1075         raise ValueError(
#    1076             f"LSTM: Expected input to be 2D or 3D, got {input.dim()}D instead"
#    1077         )
#    1078     is_batched = input.dim() == 3
#
# AttributeError: 'dict' object has no attribute 'dim'

# %%
raw_predictions, x = tft.predict(val_loader, mode="raw", return_x=True)

# Plot first sample prediction
tft.plot_prediction(x, raw_predictions, idx=0, add_loss_to_title=True)
